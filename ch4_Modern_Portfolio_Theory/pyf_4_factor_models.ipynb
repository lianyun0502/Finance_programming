# %% [markdown]
# # Factor Models
# - Referenecs
#     - Dr. Kempthorne (2013): [Factor Models](https://ocw.mit.edu/courses/mathematics/18-s096-topics-in-mathematics-with-applications-in-finance-fall-2013/lecture-notes/MIT18_S096F13_lecnote15.pdf)

# %% [markdown]
# ## Arbitrage Pricing Theory (APT)
# - The CAPM is derived from market equilibrium, the equality of asset demand and supply.
#     - This equality implies that the market portfolio must be mean-variance efficient, and a typical investor holds the market portfolio.
#     - The systematic risk embodied in the beta coefficients determines the risk premia.
# - However, the APT doesn't need any utility function and doesn't assume that return rates follow a normal distribution.
# - Ross (1976): [The arbitrage theory of capital asset pricing](https://www.sciencedirect.com/science/article/pii/0022053176900466)
#     - By **the law of one price**, two portfolios that
# have the same risk must have the same expected return (or equivalently the same price); otherwise, an **arbitrage opportunity** exists!
#         - [Arbitrage](https://en.wikipedia.org/wiki/Arbitrage): zero initial investment, bearing no risk (sure win), and positive return.
# - Let $K$ be the number of factors.
# - The arbitrage-free model can be formulated as $$R_i - R_f = \sum_{j = 1}^{K}\beta_{i, j}\left(\mathbf{E}(R_j) - R_f\right) + \varepsilon_{i}.$$
#     - You can say that CAPM is a special case of APT!
# - In APT, you can use any factor which is not necessary to be a market factor.
#     - Chen, Roll, and Ross (1986): [Economic Forces and the Stock Market](https://www.jstor.org/stable/2352710)
#         - Monthly growth in industrial production
#         - Change in expected inflation
#         - Unanticipated inflation
#         - Unanticipated change in the risk permium between risky bonds and default-free bonds
#         - Unanticipated change in the difference between the return on long-term government bonds and the return on the short-term government bonds
# - Applications of APT:
#     - Asset allocation;
#     - Computation of the cost of capital;
#     - Performance evaluation of managed funds.
# - References
#     - https://www0.gsb.columbia.edu/faculty/ghuberman/APT-Huberman-Wang.pdf

# %% [markdown]
# ## Fama-French 3-Factor Model
# - Fama and French (1993): [Common risk factors in the returns on stocks and bonds](https://www.sciencedirect.com/science/article/pii/0304405X93900235)
#     - The CAPM is the single-factor model to explain the risk premium of stocks.
#     - Fama and French consider the extra two explanatory variables in the model: (1) the market size, denoted by **SMB (small minus big)** and (2) the book-to-market ratio, denoted by **HML (high minus low)**:
#
# $$R_{i} - R_f = \beta_{M, i} (R_M - R_f) + \beta_{\text{SMB}, i} \text{SMB} + \beta_{\text{HML}, i} \text{HML} + \varepsilon_i.$$
#
# - Note that the HML factor means that value stocks ($\beta_{\text{HML}, i} > 0$) outperform growth stocks ($\beta_{\text{HML}, j} < 0$) based on the empirical evidences.
# - Fama shared 2013 Nobel Memorial Prize in Economic Sciences.
# - References
#     - https://www.nobelprize.org/prizes/economic-sciences/2013/fama/facts/
#     - Kenneth R. French's data library [link](https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html)
#     - 石川 (2019): [Eugene Fama，一段50年的傳奇](http://www.liang-xin.com/website/w/h?mt=2&mc=3194266&cc=3021364&fp=d&c=23909780)
#     - 投資思維－主動投資或被動投資？ (The Limit of Theory) [link1](https://justininvesting.wordpress.com/2018/04/19/the-limits-of-theory/) [link2](https://justininvesting.wordpress.com/2018/04/24/the-limits-of-theory-2/)
#     - [產業價值鏈資訊平台](https://ic.tpex.org.tw/index.php)

# %% [markdown]
# ### Example: Bio-Tech in Taiwan Market

# %%
# %%capture

# !wget https://www.csie.ntu.edu.tw/~d00922011/python/data/ff3_monthly_data.csv
# !pip install yfinance
# !pip install --upgrade pandas-datareader

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import statsmodels.api as sm
import yfinance as yf

raw = pd.read_csv("ff3_monthly_data.csv")
print(raw["Code"].unique())

# https://pchome.megatime.com.tw/group/mkt0/cid22.html
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# [1316 1701 1707 1708 1709 1710 1711 1712 1713 1714 1717 1718 1720 1721
#  1722 1723 1724 1725 1726 1727 1730 1731 1732 1733 1734 1735 1736 1762
#  1773 1783 1786 1789 3164 3705 4104 4106 4108 4119 4133 4137 4141 4142
#  4144 4164 4190 4720 4722 4725 4737 4739 4746 4755 4763 6452]

# %%
df = raw.groupby('Date')
df.head()
# Out:
#       Code    Date       r     MV    PB
# 0     1316  201601  1.5463   1673  1.36
# 1     1701  201601 -2.2788   5752  1.06
# 2     1707  201601 -0.8197  23649  7.45
# 3     1708  201601 -2.1809   5737  1.13
# 4     1709  201601 -2.9900   6277  0.97
# ...    ...     ...     ...    ...   ...
# 2106  1316  201904 -4.1915   2871  1.80
# 2107  1701  201904 -0.2644   5618  1.00
# 2108  1707  201904  7.7892  29233  5.50
# 2109  1708  201904  1.3592   5257  0.92
# 2110  1709  201904 -1.7543   7029  0.99
#
# [200 rows x 5 columns]

# %%
def cal_smb_hml(df):
    
    import warnings
    warnings.filterwarnings("ignore")
    
    # Categorized into two groups: B(ig) and S(mall).
    med = df["MV"].median()
    df["SB"] = df["MV"].apply(lambda x: "B" if x >= med else "S")

    # Categorized into three groups: H, M, L
    df["BM"] = 1 / df["PB"] # BM: book-to-market ratio; PB: price-to-book ratio (股價淨值比)
    low_threshold, high_threshold = df["BM"].quantile([0.3, 0.7])
    df["HML"] = df["BM"].apply(lambda x: "H" if x >= high_threshold else "M")
    df["HML"] = df.apply(lambda row: "L" if row["BM"] <= low_threshold else row["HML"], axis = 1)

    # Categorized into 6 groups
    df_SL = df.query('(SB=="S") & (HML=="L")')
    df_SM = df.query('(SB=="S") & (HML=="M")')
    df_SH = df.query('(SB=="S") & (HML=="H")')
    df_BL = df.query('(SB=="B") & (HML=="L")')
    df_BM = df.query('(SB=="B") & (HML=="M")')
    df_BH = df.query('(SB=="B") & (HML=="H")')

    # Return rate for each group
    R_SL = (df_SL["r"] * df_SL['MV']).sum() / df_SL['MV'].sum() / 100
    R_SM = (df_SM["r"] * df_SM['MV']).sum() / df_SM['MV'].sum() / 100
    R_SH = (df_SH["r"] * df_SH['MV']).sum() / df_SH['MV'].sum() / 100
    R_BL = (df_BL["r"] * df_BL['MV']).sum() / df_BL['MV'].sum() / 100
    R_BM = (df_BM["r"] * df_BM['MV']).sum() / df_BM['MV'].sum() / 100
    R_BH = (df_BH["r"] * df_BH['MV']).sum() / df_BH['MV'].sum() / 100

    # then we calculate SMB and HML
    smb = (R_SL + R_SM + R_SH - R_BL - R_BM - R_BH) / 3
    hml = (R_SH + R_BH - R_SL - R_BL) / 2
    return smb, hml

# %%
factors = []
for date, group in df:
    smb, hml = cal_smb_hml(group)
    factors.append([date, smb, hml])
    
df_factor = pd.DataFrame(factors, columns = ['Date', 'SMB', 'HML'])
del df_factor["Date"]
df_factor.head()
# Out:
#         SMB       HML
# 0 -0.013187  0.016115
# 1 -0.019467  0.024062
# 2  0.041950 -0.019357
# 3  0.008583  0.040254
# 4  0.031335 -0.085267

# %%
def monthly_return_rate_calculator(array_like):
    return array_like[-1] / array_like[0] - 1

# %%
df_Ri = pd.DataFrame(yf.download(",".join(selected_ticks), start = "2016-01-01", end = "2019-04-30")["Adj Close"])
df_Ri.columns = [x[:4] + "tw" for x in df_Ri.columns]
df_Ri = df_Ri.resample("M").apply(monthly_return_rate_calculator)
df_Ri.reset_index(inplace = True)
del df_Ri["Date"]
df_Ri.head()
# Out:
# [*********************100%***********************]  54 of 54 completed
#
# 1 Failed download:
# - 4725.TW: No data found, symbol may be delisted
#      1316tw    1701tw    1707tw  ...    4755tw    4763tw    6452tw
# 0  0.019689 -0.010363  0.008333  ...  0.033860  0.130484 -0.062674
# 1  0.012295  0.052494  0.013550  ...  0.021834 -0.004630  0.036212
# 2  0.069980 -0.032500 -0.016000  ...  0.023707  0.043860  0.057718
# 3 -0.023365 -0.026042  0.062842  ...  0.077731 -0.179592 -0.102564
# 4  0.081340  0.010753  0.030000  ... -0.003891  0.145000  0.066667
#
# [5 rows x 54 columns]

# %%
df_Rm = pd.DataFrame(yf.download("^twii", start = "2016-01-01", end = "2019-04-30")["Adj Close"]).resample("M").apply(monthly_return_rate_calculator)
df_Rm.columns = ["Rm"]
df_Rm = df_Rm.reset_index()
del df_Rm["Date"]
df_Rm.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#          Rm
# 0 -0.004148
# 1  0.031165
# 2  0.030538
# 3 -0.032301
# 4  0.029113

# %%
Rf = 1.01 ** (1 / 12) - 1
print(Rf)
# Out:
# 0.0008295381143461622

# %%
df_RimRf = df_Ri - Rf
df_RmmRf = df_Rm - Rf

df2 = pd.merge(df_RmmRf, df_factor, left_index = True, right_index = True, how = 'inner')
df3 = pd.merge(df2, df_RimRf, left_index = True, right_index = True, how = 'inner')
df3.head()
# Out:
#          Rm       SMB       HML  ...    4755tw    4763tw    6452tw
# 0 -0.004978 -0.013187  0.016115  ...  0.033030  0.129654 -0.063504
# 1  0.030336 -0.019467  0.024062  ...  0.021005 -0.005459  0.035382
# 2  0.029709  0.041950 -0.019357  ...  0.022877  0.043030  0.056888
# 3 -0.033131  0.008583  0.040254  ...  0.076902 -0.180421 -0.103394
# 4  0.028284  0.031335 -0.085267  ... -0.004721  0.144170  0.065837
#
# [5 rows x 57 columns]

# %%
for stock in df3.columns[3:]:
    model = sm.OLS(df3[stock], sm.add_constant(df3[['Rm', 'SMB', 'HML']].values))
    result = model.fit()
    print(result.summary())
    print()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1316tw   R-squared:                       0.204
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     3.080
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0396
# Time:                        13:16:34   Log-Likelihood:                 55.996
# No. Observations:                  40   AIC:                            -104.0
# Df Residuals:                      36   BIC:                            -97.24
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0066      0.011      0.603      0.550      -0.016       0.029
# x1             1.0226      0.369      2.768      0.009       0.273       1.772
# x2             0.7529      0.431      1.747      0.089      -0.121       1.627
# x3             0.6313      0.382      1.651      0.107      -0.144       1.407
# ==============================================================================
# Omnibus:                       20.295   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.874
# Skew:                           1.473   Prob(JB):                     3.26e-07
# Kurtosis:                       6.040   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1701tw   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     7.238
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           0.000638
# Time:                        13:16:34   Log-Likelihood:                 83.379
# No. Observations:                  40   AIC:                            -158.8
# Df Residuals:                      36   BIC:                            -152.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0064      0.006     -1.157      0.255      -0.018       0.005
# x1             0.7006      0.186      3.761      0.001       0.323       1.078
# x2            -0.2438      0.217     -1.122      0.269      -0.685       0.197
# x3            -0.2780      0.193     -1.442      0.158      -0.669       0.113
# ==============================================================================
# Omnibus:                        3.962   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                2.678
# Skew:                           0.527   Prob(JB):                        0.262
# Kurtosis:                       3.704   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1707tw   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     2.487
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0761
# Time:                        13:16:34   Log-Likelihood:                 50.326
# No. Observations:                  40   AIC:                            -92.65
# Df Residuals:                      36   BIC:                            -85.90
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0034      0.013     -0.268      0.791      -0.029       0.022
# x1             0.3927      0.426      0.923      0.362      -0.471       1.256
# x2            -0.4156      0.497     -0.837      0.408      -1.423       0.592
# x3            -0.8922      0.441     -2.025      0.050      -1.786       0.001
# ==============================================================================
# Omnibus:                        1.659   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.436   Jarque-Bera (JB):                0.756
# Skew:                          -0.224   Prob(JB):                        0.685
# Kurtosis:                       3.502   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1708tw   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     6.826
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           0.000928
# Time:                        13:16:34   Log-Likelihood:                 77.174
# No. Observations:                  40   AIC:                            -146.3
# Df Residuals:                      36   BIC:                            -139.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0096      0.006     -1.494      0.144      -0.023       0.003
# x1             0.8785      0.218      4.038      0.000       0.437       1.320
# x2            -0.2936      0.254     -1.157      0.255      -0.808       0.221
# x3            -0.0976      0.225     -0.434      0.667      -0.554       0.359
# ==============================================================================
# Omnibus:                        5.689   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                4.527
# Skew:                           0.796   Prob(JB):                        0.104
# Kurtosis:                       3.427   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1709tw   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     6.082
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):            0.00185
# Time:                        13:16:34   Log-Likelihood:                 78.968
# No. Observations:                  40   AIC:                            -149.9
# Df Residuals:                      36   BIC:                            -143.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.006      0.311      0.757      -0.011       0.014
# x1             0.8443      0.208      4.059      0.000       0.422       1.266
# x2             0.2022      0.243      0.833      0.410      -0.290       0.694
# x3             0.0828      0.215      0.385      0.703      -0.354       0.519
# ==============================================================================
# Omnibus:                        5.759   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                7.236
# Skew:                           0.185   Prob(JB):                       0.0268
# Kurtosis:                       5.050   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1710tw   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     4.581
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):            0.00812
# Time:                        13:16:34   Log-Likelihood:                 53.162
# No. Observations:                  40   AIC:                            -98.32
# Df Residuals:                      36   BIC:                            -91.57
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0070      0.012     -0.598      0.553      -0.031       0.017
# x1             0.3772      0.397      0.951      0.348      -0.427       1.181
# x2            -1.4261      0.463     -3.082      0.004      -2.364      -0.488
# x3            -0.3568      0.410     -0.869      0.390      -1.189       0.476
# ==============================================================================
# Omnibus:                        2.370   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.306   Jarque-Bera (JB):                1.622
# Skew:                           0.488   Prob(JB):                        0.444
# Kurtosis:                       3.150   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1711tw   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     5.986
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):            0.00203
# Time:                        13:16:34   Log-Likelihood:                 79.905
# No. Observations:                  40   AIC:                            -151.8
# Df Residuals:                      36   BIC:                            -145.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0091      0.006     -1.523      0.136      -0.021       0.003
# x1             0.6915      0.203      3.403      0.002       0.279       1.104
# x2            -0.3878      0.237     -1.636      0.111      -0.869       0.093
# x3            -0.2392      0.210     -1.137      0.263      -0.666       0.187
# ==============================================================================
# Omnibus:                        4.071   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                2.962
# Skew:                           0.408   Prob(JB):                        0.227
# Kurtosis:                       4.054   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1712tw   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     3.721
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0199
# Time:                        13:16:34   Log-Likelihood:                 88.488
# No. Observations:                  40   AIC:                            -169.0
# Df Residuals:                      36   BIC:                            -162.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0123      0.005      2.549      0.015       0.003       0.022
# x1             0.5330      0.164      3.251      0.002       0.201       0.866
# x2             0.2567      0.191      1.342      0.188      -0.131       0.645
# x3             0.2350      0.170      1.385      0.175      -0.109       0.579
# ==============================================================================
# Omnibus:                        2.792   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.248   Jarque-Bera (JB):                1.935
# Skew:                           0.529   Prob(JB):                        0.380
# Kurtosis:                       3.206   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1713tw   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     1.885
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.150
# Time:                        13:16:34   Log-Likelihood:                 80.196
# No. Observations:                  40   AIC:                            -152.4
# Df Residuals:                      36   BIC:                            -145.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.006      0.396      0.695      -0.010       0.014
# x1             0.3940      0.202      1.953      0.059      -0.015       0.803
# x2            -0.2282      0.235     -0.970      0.339      -0.706       0.249
# x3            -0.0437      0.209     -0.209      0.835      -0.467       0.380
# ==============================================================================
# Omnibus:                        5.075   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.079   Jarque-Bera (JB):                3.712
# Skew:                           0.631   Prob(JB):                        0.156
# Kurtosis:                       3.797   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1714tw   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                     3.465
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0261
# Time:                        13:16:34   Log-Likelihood:                 67.086
# No. Observations:                  40   AIC:                            -126.2
# Df Residuals:                      36   BIC:                            -119.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0099      0.008     -1.194      0.240      -0.027       0.007
# x1             0.6949      0.280      2.482      0.018       0.127       1.263
# x2            -0.4781      0.327     -1.464      0.152      -1.141       0.184
# x3            -0.0087      0.290     -0.030      0.976      -0.596       0.579
# ==============================================================================
# Omnibus:                        6.136   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                4.829
# Skew:                           0.678   Prob(JB):                       0.0894
# Kurtosis:                       4.028   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1717tw   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                     12.92
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           6.99e-06
# Time:                        13:16:34   Log-Likelihood:                 86.544
# No. Observations:                  40   AIC:                            -165.1
# Df Residuals:                      36   BIC:                            -158.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0047      0.005     -0.915      0.366      -0.015       0.006
# x1             0.8696      0.172      5.052      0.000       0.521       1.219
# x2            -0.5220      0.201     -2.599      0.013      -0.929      -0.115
# x3            -0.1968      0.178     -1.105      0.277      -0.558       0.165
# ==============================================================================
# Omnibus:                        0.323   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.851   Jarque-Bera (JB):                0.188
# Skew:                           0.161   Prob(JB):                        0.910
# Kurtosis:                       2.908   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1718tw   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     2.516
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0737
# Time:                        13:16:34   Log-Likelihood:                 60.654
# No. Observations:                  40   AIC:                            -113.3
# Df Residuals:                      36   BIC:                            -106.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.010     -0.284      0.778      -0.022       0.017
# x1             0.4431      0.329      1.348      0.186      -0.224       1.110
# x2            -0.7775      0.384     -2.027      0.050      -1.556       0.001
# x3            -0.2164      0.340     -0.636      0.529      -0.907       0.474
# ==============================================================================
# Omnibus:                       14.100   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.713
# Skew:                           1.116   Prob(JB):                     0.000235
# Kurtosis:                       5.245   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1720tw   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     3.008
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0428
# Time:                        13:16:34   Log-Likelihood:                 68.599
# No. Observations:                  40   AIC:                            -129.2
# Df Residuals:                      36   BIC:                            -122.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0116      0.008     -1.455      0.154      -0.028       0.005
# x1             0.3607      0.270      1.338      0.189      -0.186       0.907
# x2            -0.2391      0.315     -0.760      0.452      -0.877       0.399
# x3            -0.5542      0.279     -1.986      0.055      -1.120       0.012
# ==============================================================================
# Omnibus:                       20.679   Durbin-Watson:                   2.405
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.954
# Skew:                           1.174   Prob(JB):                     3.86e-11
# Kurtosis:                       7.823   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1721tw   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     1.497
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.232
# Time:                        13:16:34   Log-Likelihood:                 62.369
# No. Observations:                  40   AIC:                            -116.7
# Df Residuals:                      36   BIC:                            -110.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0096      0.009     -1.030      0.310      -0.028       0.009
# x1             0.5752      0.315      1.826      0.076      -0.064       1.214
# x2             0.3337      0.368      0.908      0.370      -0.412       1.079
# x3             0.0991      0.326      0.304      0.763      -0.562       0.760
# ==============================================================================
# Omnibus:                        2.358   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.308   Jarque-Bera (JB):                1.866
# Skew:                           0.528   Prob(JB):                        0.393
# Kurtosis:                       2.940   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1722tw   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.525
# Method:                 Least Squares   F-statistic:                     15.36
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           1.35e-06
# Time:                        13:16:34   Log-Likelihood:                 90.578
# No. Observations:                  40   AIC:                            -173.2
# Df Residuals:                      36   BIC:                            -166.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0047      0.005     -1.015      0.317      -0.014       0.005
# x1             0.9531      0.156      6.125      0.000       0.637       1.269
# x2            -0.1540      0.182     -0.848      0.402      -0.522       0.214
# x3            -0.1402      0.161     -0.871      0.390      -0.467       0.186
# ==============================================================================
# Omnibus:                        1.858   Durbin-Watson:                   1.433
# Prob(Omnibus):                  0.395   Jarque-Bera (JB):                1.733
# Skew:                           0.475   Prob(JB):                        0.420
# Kurtosis:                       2.629   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1723tw   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     4.806
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):            0.00646
# Time:                        13:16:34   Log-Likelihood:                 78.432
# No. Observations:                  40   AIC:                            -148.9
# Df Residuals:                      36   BIC:                            -142.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0064      0.006     -1.020      0.314      -0.019       0.006
# x1             0.3216      0.211      1.525      0.136      -0.106       0.749
# x2            -0.6306      0.246     -2.564      0.015      -1.129      -0.132
# x3            -0.5954      0.218     -2.729      0.010      -1.038      -0.153
# ==============================================================================
# Omnibus:                        0.098   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.952   Jarque-Bera (JB):                0.018
# Skew:                          -0.020   Prob(JB):                        0.991
# Kurtosis:                       2.903   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1724tw   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     3.877
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0168
# Time:                        13:16:34   Log-Likelihood:                 80.491
# No. Observations:                  40   AIC:                            -153.0
# Df Residuals:                      36   BIC:                            -146.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0027      0.006     -0.461      0.647      -0.015       0.009
# x1             0.6808      0.200      3.400      0.002       0.275       1.087
# x2             0.1891      0.234      0.809      0.424      -0.285       0.663
# x3             0.2152      0.207      1.038      0.306      -0.205       0.635
# ==============================================================================
# Omnibus:                        5.030   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.081   Jarque-Bera (JB):                3.785
# Skew:                           0.549   Prob(JB):                        0.151
# Kurtosis:                       4.031   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1725tw   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.466
# Method:                 Least Squares   F-statistic:                     12.34
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           1.06e-05
# Time:                        13:16:34   Log-Likelihood:                 82.956
# No. Observations:                  40   AIC:                            -157.9
# Df Residuals:                      36   BIC:                            -151.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0050      0.006     -0.892      0.378      -0.016       0.006
# x1             0.6166      0.188      3.275      0.002       0.235       0.998
# x2             0.2522      0.220      1.148      0.259      -0.193       0.698
# x3            -0.4306      0.195     -2.210      0.034      -0.826      -0.035
# ==============================================================================
# Omnibus:                        0.054   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.973   Jarque-Bera (JB):                0.185
# Skew:                          -0.079   Prob(JB):                        0.912
# Kurtosis:                       2.707   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1726tw   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     3.907
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):             0.0163
# Time:                        13:16:34   Log-Likelihood:                 89.094
# No. Observations:                  40   AIC:                            -170.2
# Df Residuals:                      36   BIC:                            -163.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.005     -0.272      0.787      -0.011       0.008
# x1             0.4481      0.161      2.775      0.009       0.121       0.776
# x2            -0.2723      0.188     -1.445      0.157      -0.654       0.110
# x3            -0.0422      0.167     -0.253      0.802      -0.381       0.297
# ==============================================================================
# Omnibus:                        0.986   Durbin-Watson:                   2.323
# Prob(Omnibus):                  0.611   Jarque-Bera (JB):                0.273
# Skew:                           0.059   Prob(JB):                        0.872
# Kurtosis:                       3.387   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1727tw   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.161
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.338
# Time:                        13:16:34   Log-Likelihood:                 65.839
# No. Observations:                  40   AIC:                            -123.7
# Df Residuals:                      36   BIC:                            -116.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0049      0.009     -0.573      0.570      -0.022       0.012
# x1             0.1706      0.289      0.591      0.559      -0.415       0.756
# x2            -0.5433      0.337     -1.612      0.116      -1.227       0.140
# x3            -0.2264      0.299     -0.757      0.454      -0.833       0.380
# ==============================================================================
# Omnibus:                       13.060   Durbin-Watson:                   2.247
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               31.840
# Skew:                           0.545   Prob(JB):                     1.22e-07
# Kurtosis:                       7.233   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1730tw   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     1.381
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.264
# Time:                        13:16:34   Log-Likelihood:                 66.717
# No. Observations:                  40   AIC:                            -125.4
# Df Residuals:                      36   BIC:                            -118.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0162      0.008      1.940      0.060      -0.001       0.033
# x1             0.0117      0.283      0.041      0.967      -0.561       0.585
# x2            -0.0465      0.330     -0.141      0.889      -0.715       0.622
# x3            -0.4417      0.292     -1.511      0.140      -1.035       0.151
# ==============================================================================
# Omnibus:                       14.127   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.942
# Skew:                           1.059   Prob(JB):                     0.000127
# Kurtosis:                       5.506   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1731tw   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     6.411
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):            0.00136
# Time:                        13:16:34   Log-Likelihood:                 87.483
# No. Observations:                  40   AIC:                            -167.0
# Df Residuals:                      36   BIC:                            -160.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0050      0.005     -1.000      0.324      -0.015       0.005
# x1             0.5943      0.168      3.535      0.001       0.253       0.935
# x2             0.1477      0.196      0.753      0.456      -0.250       0.546
# x3            -0.1145      0.174     -0.658      0.515      -0.467       0.238
# ==============================================================================
# Omnibus:                        5.401   Durbin-Watson:                   2.485
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                4.032
# Skew:                           0.687   Prob(JB):                        0.133
# Kurtosis:                       3.731   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1732tw   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     1.870
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.152
# Time:                        13:16:34   Log-Likelihood:                 77.176
# No. Observations:                  40   AIC:                            -146.4
# Df Residuals:                      36   BIC:                            -139.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0095      0.006     -1.474      0.149      -0.023       0.004
# x1             0.3646      0.218      1.676      0.102      -0.077       0.806
# x2            -0.1987      0.254     -0.783      0.439      -0.713       0.316
# x3            -0.2404      0.225     -1.068      0.293      -0.697       0.216
# ==============================================================================
# Omnibus:                       18.809   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.322
# Skew:                           0.974   Prob(JB):                     3.21e-11
# Kurtosis:                       8.020   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 1733tw   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     10.50
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           4.19e-05
# Time:                        13:16:34   Log-Likelihood:                 63.817
# No. Observations:                  40   AIC:                            -119.6
# Df Residuals:                      36   BIC:                            -112.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0135      0.009     -1.508      0.140      -0.032       0.005
# x1             0.4907      0.304      1.615      0.115      -0.125       1.107
# x2             0.6260      0.354      1.766      0.086      -0.093       1.345
# x3            -0.6828      0.314     -2.171      0.037      -1.320      -0.045
# ==============================================================================
# Omnibus:                        0.328   Durbin-Watson:                   1.687
# Prob(Omnibus):                  0.849   Jarque-Bera (JB):                0.113
# Skew:                           0.130   Prob(JB):                        0.945
# Kurtosis:                       2.980   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ...
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4722tw   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     8.154
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           0.000285
# Time:                        13:16:34   Log-Likelihood:                 82.478
# No. Observations:                  40   AIC:                            -157.0
# Df Residuals:                      36   BIC:                            -150.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0038      0.006     -0.681      0.500      -0.015       0.008
# x1             0.9069      0.191      4.760      0.000       0.520       1.293
# x2             0.1355      0.222      0.610      0.546      -0.315       0.586
# x3             0.0753      0.197      0.382      0.705      -0.325       0.475
# ==============================================================================
# Omnibus:                        0.121   Durbin-Watson:                   1.755
# Prob(Omnibus):                  0.941   Jarque-Bera (JB):                0.303
# Skew:                          -0.095   Prob(JB):                        0.860
# Kurtosis:                       2.619   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4725tw   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):                nan
# Time:                        13:16:34   Log-Likelihood:                    nan
# No. Observations:                  40   AIC:                               nan
# Df Residuals:                      36   BIC:                               nan
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const             nan        nan        nan        nan         nan         nan
# x1                nan        nan        nan        nan         nan         nan
# x2                nan        nan        nan        nan         nan         nan
# x3                nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4737tw   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                     6.851
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           0.000906
# Time:                        13:16:34   Log-Likelihood:                 57.922
# No. Observations:                  40   AIC:                            -107.8
# Df Residuals:                      36   BIC:                            -101.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0073      0.010     -0.698      0.490      -0.028       0.014
# x1             0.4600      0.352      1.307      0.200      -0.254       1.174
# x2             0.5398      0.411      1.314      0.197      -0.293       1.373
# x3            -0.6736      0.364     -1.849      0.073      -1.413       0.065
# ==============================================================================
# Omnibus:                        7.839   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                6.680
# Skew:                           0.944   Prob(JB):                       0.0354
# Kurtosis:                       3.667   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4739tw   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.056
# Method:                 Least Squares   F-statistic:                    0.3118
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.817
# Time:                        13:16:34   Log-Likelihood:                 28.730
# No. Observations:                  40   AIC:                            -49.46
# Df Residuals:                      36   BIC:                            -42.70
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0206      0.022      0.955      0.346      -0.023       0.064
# x1             0.6652      0.730      0.911      0.368      -0.816       2.146
# x2             0.1154      0.852      0.135      0.893      -1.613       1.844
# x3             0.3704      0.756      0.490      0.627      -1.163       1.903
# ==============================================================================
# Omnibus:                        6.146   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.267
# Skew:                           0.881   Prob(JB):                       0.0718
# Kurtosis:                       3.240   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4746tw   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     7.571
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           0.000475
# Time:                        13:16:34   Log-Likelihood:                 51.993
# No. Observations:                  40   AIC:                            -95.99
# Df Residuals:                      36   BIC:                            -89.23
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0182      0.012     -1.509      0.140      -0.043       0.006
# x1             1.0669      0.408      2.613      0.013       0.239       1.895
# x2             1.1345      0.476      2.381      0.023       0.168       2.101
# x3            -0.1697      0.423     -0.402      0.690      -1.027       0.687
# ==============================================================================
# Omnibus:                        5.287   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                6.319
# Skew:                          -0.132   Prob(JB):                       0.0425
# Kurtosis:                       4.929   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4755tw   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1.467
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.240
# Time:                        13:16:34   Log-Likelihood:                 49.943
# No. Observations:                  40   AIC:                            -91.89
# Df Residuals:                      36   BIC:                            -85.13
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0193      0.013      1.520      0.137      -0.006       0.045
# x1             0.8979      0.430      2.089      0.044       0.026       1.769
# x2             0.2252      0.501      0.449      0.656      -0.792       1.242
# x3             0.3621      0.445      0.814      0.421      -0.540       1.264
# ==============================================================================
# Omnibus:                       10.950   Durbin-Watson:                   1.574
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               10.580
# Skew:                           1.030   Prob(JB):                      0.00504
# Kurtosis:                       4.450   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 4763tw   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.9407
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):              0.431
# Time:                        13:16:34   Log-Likelihood:                 48.562
# No. Observations:                  40   AIC:                            -89.12
# Df Residuals:                      36   BIC:                            -82.37
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0106      0.013      0.810      0.423      -0.016       0.037
# x1             0.7266      0.445      1.633      0.111      -0.176       1.629
# x2             0.3317      0.519      0.639      0.527      -0.721       1.384
# x3             0.2730      0.460      0.593      0.557      -0.661       1.207
# ==============================================================================
# Omnibus:                        2.308   Durbin-Watson:                   2.210
# Prob(Omnibus):                  0.315   Jarque-Bera (JB):                1.572
# Skew:                          -0.480   Prob(JB):                        0.456
# Kurtosis:                       3.145   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 6452tw   R-squared:                       0.463
# Model:                            OLS   Adj. R-squared:                  0.418
# Method:                 Least Squares   F-statistic:                     10.33
# Date:                Sat, 03 Jul 2021   Prob (F-statistic):           4.80e-05
# Time:                        13:16:34   Log-Likelihood:                 40.192
# No. Observations:                  40   AIC:                            -72.38
# Df Residuals:                      36   BIC:                            -65.63
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0224      0.016     -1.382      0.175      -0.055       0.010
# x1             2.6268      0.548      4.790      0.000       1.515       3.739
# x2            -1.0081      0.640     -1.575      0.124      -2.306       0.290
# x3            -0.5905      0.568     -1.040      0.305      -1.742       0.561
# ==============================================================================
# Omnibus:                        3.408   Durbin-Watson:                   2.199
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                2.289
# Skew:                          -0.352   Prob(JB):                        0.318
# Kurtosis:                       3.938   Cond. No.                         54.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Extension: Carhart 4-Factor Model
# - Carhart (1997): [On Persistence in Mutual Fund Performance](https://onlinelibrary.wiley.com/doi/full/10.1111/j.1540-6261.1997.tb03808.x)
# - References
#     - https://en.wikipedia.org/wiki/Carhart_four-factor_model

# %% [markdown]
# ## Extension: Fama-French 5-Factor Model
# - References
#     - Fama and French (2015): [A Five-Factor Asset Pricing Model](https://www.sciencedirect.com/science/article/abs/pii/S0304405X14002323)
#     - Description of Fama/French 5 Factors (2x3) [link](https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/Data_Library/f-f_5_factors_2x3.html)

# %% [markdown]
# ## AQR: Buffett's Alpha
# - Frazzini, Kabiller, and Pedersen (2018): [Buffett's Alpha](https://www.tandfonline.com/doi/full/10.2469/faj.v74.n4.3)
#     - Asness, Moskowitz, and Pedersen (2013): [Value and Momentum Everywhere](https://www.aqr.com/Insights/Research/Journal-Article/Value-and-Momentum-Everywhere)
#     - Frazzini and H. Pedersen (2014): [Betting Against Beta](https://www.sciencedirect.com/science/article/pii/S0304405X13002675)
#         - 石川 (2019): [BAB vs. BABAB](https://zhuanlan.zhihu.com/p/58479814)
#     - Asness, Frazzini, and H. Pedersen (2018): [Quality Minus Junk](https://link.springer.com/article/10.1007/s11142-018-9470-2)
#     - Gupta and Kelly (2019): [Factor Momentum Everywhere](https://www.aqr.com/Insights/Research/Working-Paper/Factor-Momentum-Everywhere)
# - Glossary
#     - [名詞解釋：何謂13F報告](https://news.cnyes.com/news/id/4568967)

# %% [markdown]
# ## Example: Factor ETFs
# - [Vanguard U.S. Momentum Factor ETF](https://www.etf.com/VFMO) (VFMO)
# - [Vanguard U.S. Multifactor ETF](https://www.etf.com/VFMF) (VFMF)
# - [Top 25 Quality Factor ETFs](https://etfdb.com/themes/quality-factor-etfs/)

# %% [markdown]
# ### Smart Beta?
# - [富邦道瓊臺灣優質高息30ETF基金](https://www.moneydj.com/ETF/X/Basic/Basic0004.xdjhtm?etfid=00730.TW) (00730.TW)
#     - [富邦臺灣優質高息ETF（00730）完整介紹：平均殖利率4.85%！能取代元大高股息嗎？](https://earning.tw/what-is-00730-etf), 2018.02.21
# * References
#     - Jason Hsu and Vitali Kalesnik (2014): [Finding Smart Beta in the Factor Zoo](https://www.researchaffiliates.com/en_us/publications/articles/223_finding_smart_beta_in_the_factor_zoo.html)
#     - Saud AlMahdi (2015): [Smart beta portfolio optimization](https://file.scirp.org/pdf/JMF_2015052615053472.pdf)

# %% [markdown]
# ## MSCI Barra Multi-Factor Analysis
# - MSCI refers to **M**organ **S**tanley **C**apital **I**nternational.
#     - [MSCI 是什麼 ? 最新增減個股一覽](https://www.stockfeel.com.tw/msci-%e5%8f%b0%e7%81%a3-%e6%88%90%e5%88%86%e8%82%a1-%e6%ac%8a%e9%87%8d/)
#     - [MSCI Taiwan Index](https://histock.tw/stock/mscitaiwan.aspx)
# - Barra Risk Factor Analysis, proposed by [Barr Rosenberg](http://www.barrrosenberg.com/) in 1975, incorporates over 40 data metrics, including earnings growth, share turnover and senior debt rating.
# - References
#     - [MSCI Barra Factor Indexes Methodology](https://www.msci.com/eqb/methodology/meth_docs/MSCI_Barra_Factor_Indexes_Methodology_Mar18.pdf), 2018

# %% [markdown]
# ## Factor Zoo & Factor War
# - Kakushadze (2015): [WorldQuant 101 Alphas](https://arxiv.org/ftp/arxiv/papers/1601/1601.00991.pdf)
# - Feng, Giglio, and Xiu (2018): [Taming the Factor Zoo](https://www.aqr.com/About-Us/AQR-Insight-Award/2018/Taming-the-Factor-Zoo)
#     - Feng, Giglio, and Xiu (2020): [Taming the Factor Zoo: A Test of New Factors](https://onlinelibrary.wiley.com/doi/abs/10.1111/jofi.12883)
# - Kewei Hou, Chen Xue, and Lu Zhang (2020): [Replicating Anomalies](http://global-q.org/uploads/1/2/2/6/122679606/houxuezhang2020rfs.pdf)
#     - 石川 (2019): [从 Factor Zoo 到 Factor War，实证资产定价走向何方？](https://zhuanlan.zhihu.com/p/72957469)
# - 石川 (2019): [股票多因子模型的回归检验](https://zhuanlan.zhihu.com/p/40984029)
#     - Hansen (1982): [Large Sample Properties of Generalized Method of Moments Estimators](https://www.jstor.org/stable/1912775)
#     - Shanken (1992): [On the Estimation of Beta-Pricing Models](https://www.jstor.org/stable/2962011)
#     - Petersen (2009): [Estimating Standard Errors in Finance Panel Data Sets: Comparing Approaches](https://www.jstor.org/stable/40056916)
# - References
#     - Mateus, Mateus, and Todorovic (2019): [Review of new trends in the literature on factor models and mutual fund performance](https://www.sciencedirect.com/science/article/abs/pii/S1057521918305222)
